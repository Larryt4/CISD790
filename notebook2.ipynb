# %%
# %matplotlib inline
from collections import defaultdict
import json
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl
import numpy as np
from numpy import searchsorted

# %%
#read in states file
infile = r'data2\stateCodes.csv'
states = pd.read_csv(infile, names=['stateName', 'stateCode'])

# %%
#create dataframe using states to read in each birth records files
pieces = []
columns = ['state','sex','year','name','births']

for stateCode in states.stateCode:
    path = r'data2\%s.txt' %stateCode
    frame = pd.read_csv(path, names=columns)
    pieces.append(frame)
allNames = pd.concat(pieces, ignore_index=True)
allNames = allNames[allNames.year >= 2000]

# %%
#add proportion column
def add_prop(group):
    births = group.births.astype(float)
    group['prop'] = births/births.sum()
    return group

allNames = allNames.groupby(['year','state','sex']).apply(add_prop)

# %%
allNames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1155989 entries, 55412 to 5459280
# Data columns (total 6 columns):
# state     1155989  non-null values
# sex       1155989  non-null values
# year      1155989  non-null values
# name      1155989  non-null values
# births    1155989  non-null values
# prop      1155989  non-null values
# dtypes: float64(1), int64(2), object(3)

# %%
#extract top 1000 of each state,sex
pieces = []
for year, group in allNames.groupby(['year', 'sex', 'state']):
    pieces.append(group.sort_index(by='births', ascending=False)[:1000])
top1000 = pd.concat(pieces, ignore_index=True)

# %%
top1000[:5]
# Out:
#   state sex  year     name  births      prop
# 0    AK   F  2000   Hannah      58  0.025450
# 1    AK   F  2000  Madison      50  0.021939
# 2    AK   F  2000    Emily      48  0.021062
# 3    AK   F  2000    Sarah      39  0.017113
# 4    AK   F  2000   Ashley      36  0.015796
#
# [5 rows x 6 columns]

# %%
def regionsToGeometry(geofile):
    """Geofile is a json geography file. Returns a dict
    mapping each feature id to a list of polygons 
    describing its geography"""
    res = defaultdict(list)
    data = json.load(file(geofile))
    for f in data['features']:
        region = f['id']
        geo = f['geometry']
        if geo['type'] == 'Polygon':
            for coords in geo['coordinates']:
                res[region].append(coords)
        elif geo['type'] == 'MultiPolygon':
            for polygon in geo['coordinates']:
                res[region].extend(polygon)
    return res

# %%
geofile = 'data2/us-states.json'
regions = regionsToGeometry(geofile)

# %%
def drawRegion(regions, region, ax, **kwargs):
    for polygon in regions[region]:
        xs, ys = zip(*polygon)
        ax.fill(xs, ys, **kwargs)
    return ax

# %%
#delete Alaska and Hawaii
for s in ['AK', 'HI']:
    del regions[s]

# %%
def drawRegions(regions, **kwargs):
    fig = plt.figure(figsize=(14,8))
    ax = plt.gca()
    ax.set_xticks([])
    ax.set_yticks([])
    # continental US x and y range
    ax.set_xlim(-130, -60)
    ax.set_ylim(22, 52)
    for region in regions.keys():
        drawRegion(regions, region, ax, **kwargs)

# %%
drawRegions(regions)

# %%
pop = pd.read_csv('data2/statesByPopulation.csv', names=['state', 'pop'])
popDF = pop.set_index('state')
popDF
# Out:
#             pop
# state
# AL      4779736
# AK       710231
# AZ      6392017
# AR      2915918
# CA     37253956
# CO      5029196
# CT      3574097
# DE       897934
# FL     18801310
# GA      9687653
# HI      1360301
# ID      1567582
# IL     12830632
# IN      6483802
# IA      3046355
# KS      2853118
# KY      4339367
# LA      4533372
# ME      1328361
# MD      5773552
# MA      6547629
# MI      9883640
# MN      5303925
# MS      2967297
# MO      5988927
# MT       989415
# NE      1826341
# NV      2700551
# NH      1316470
# NJ      8791894
# NM      2059179
# NY     19378102
# NC      9535483
# ND       672591
# OH     11536504
# OK      3751351
# OR      3831074
# PA     12702379
# RI      1052567
# SC      4625364
# SD       814180
# TN      6346105
# TX     25145561
# UT      2763885
# VT       625741
# VA      8001024
# WA      6724540
# WV      1852994
# WI      5686986
# WY       563626
#
# [50 rows x 1 columns]

# %%
def makeChoroplethMap(regions, data, col, label=None, cmap=cm.Spectral, figsize=(15,8), **kwargs):
    fig = plt.figure()
    fig.set_figwidth(figsize[0])
    fig.set_figheight(figsize[1])
    ax = plt.gca()
    ax.set_position([0.0, 0.0, 0.94, 0.96])
    ax.set_xlim(-130, -60)
    ax.set_ylim(22, 52)
    knownStates = set(data.index)
    vmin = data[col].min()
    vmax = data[col].max()
    norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
    for region in regions:
        if region in knownStates:
            color = cmap(norm(data.ix[region][col]))
            drawRegion(regions, region, ax, color=color, **kwargs)
    if label:
        ax.set_title(label, loc='center')
    ax1 = fig.add_axes([0.90, 0.0, 0.04, 0.96])
    cb1=mpl.colorbar.ColorbarBase(ax1, cmap=cmap, norm=norm, orientation='vertical')
    ax.set_xticks([])
    ax.set_yticks([])
    fig.canvas.draw()
    return ax

# %%
makeChoroplethMap(regions, popDF, 'pop', label='Population by state', cmap=cm.RdBu)

# %%
#test the data with sample code
def get_quantile_count(group, q=.5): 
    group = group.sort_index(by='prop', ascending=False)
    arr = pd.np.array(group.prop.cumsum())
    return arr.searchsorted(q) + 1
yr2002 = top1000[top1000.year == 2002] 
div2002 = yr2002.groupby(['state', 'sex']).apply(get_quantile_count) 
div2002 = div2002.unstack('sex') 
makeChoroplethMap(regions, div2002, 'M', label='Diversity (50%):2002, Male')

# %%
def makeMap(regions, data, year, sex, q=0.5, cmap=cm.Spectral, **kwargs):
    def get_quantile_count(group, q=q): 
        group = group.sort_index(by='prop', ascending=False)
        arr = pd.np.array(group.prop.cumsum())
        return arr.searchsorted(q) + 1
    yr = data[data.year == year] 
    div = yr.groupby(['state', 'sex']).apply(get_quantile_count) 
    div = div.unstack('sex')
    sexStr = 'Male' if sex=='M'else 'Female'
    labelStr = 'Diversity ('+'%1.0f' %(q*100) +'%):'+str(year)+', '+sexStr
    makeChoroplethMap(regions, div, 'M', label=labelStr, cmap=cmap)

# %%
makeMap(regions, top1000, 2002, 'M', q=0.5)

# %%
makeMap(regions, top1000, 2008, 'F', q=0.42, cmap = cm.summer)

# %%
makeMap(regions, top1000, 2010, 'M', q=0.65, cmap = cm.winter)

# %%
makeMap(regions, top1000, 2001, 'F', q=0.20, cmap = cm.autumn)

# %%
#cerate dataset for Tableau
top1000forTab = top1000.groupby(['year','state', 'sex']).apply(get_quantile_count)
top1000forTab = top1000forTab.unstack('year')
top1000forTab = top1000forTab.unstack('sex')
top1000forTab.to_csv(r'data2\top1000forTab.csv')

# %%
top1000forTab
# Out:
# year   2000      2001      2002      2003      2004      2005      2006      \
# sex       F   M     F   M     F   M     F   M     F   M     F   M     F   M
# state
# AK       47  40    51  42    51  42    51  47    52  46    54  48    57  48
# AL       74  47    73  51    74  53    81  57    86  59    91  62    96  64
# AR       67  52    66  54    75  56    78  59    81  64    85  67    90  68
# AZ      113  64   120  66   120  66   124  68   127  73   132  74   135  76
# CA      132  66   138  69   138  69   141  71   147  73   154  76   160  78
# CO       99  64   101  66   102  68   106  70   111  74   115  75   122  78
# CT       58  36    61  38    63  38    64  39    66  42    69  45    70  49
# DC       64  44    62  44    59  48    62  49    66  49    60  46    68  53
# DE       37  30    42  33    45  36    46  38    49  36    49  39    54  43
# FL      104  62   109  64   111  67   117  71   123  73   128  76   134  77
# GA       99  63   107  66   111  68   119  73   129  76   136  80   143  81
# HI       66  47    63  48    56  51    62  51    72  56    68  54    73  61
# IA       59  51    62  54    65  56    68  58    70  61    78  63    76  65
# ID       64  57    65  59    68  60    69  64    75  67    80  70    81  70
# IL      105  63   112  66   112  68   116  71   123  72   128  76   130  79
# IN       76  54    81  57    83  57    89  61    93  66    96  68   102  70
# KS       74  58    75  60    83  63    85  67    87  68    88  71    93  73
# KY       58  40    60  42    63  45    66  48    98  66    76  53    80  56
# LA       82  70    82  71    86  72    92  72    94  76    99  77    98  78
# MA       66  36    69  39    70  40    73  42    74  43    78  46    83  50
# MD       74  46    78  49    81  50    86  53    91  56    99  59   105  63
# ME       42  35    41  35    42  36    45  40    45  40    46  42    46  42
# MI       84  53    85  55    87  58    93  61    95  64   100  66   107  68
# MN       65  47    71  48    70  51    76  52    81  57    85  60    90  63
# MO       71  52    71  55    76  56    79  60    85  63    90  65    94  68
# MS       71  56    72  56    75  56    81  60    83  62    88  65    99  69
# MT       46  48    46  50    45  50    51  53    48  53    51  53    55  57
# NC       87  54    96  56    98  57   105  61   112  64   118  68   125  71
# ND       35  40    41  41    38  44    39  43    39  43    41  47    43  45
# NE       60  49    60  53    64  56    66  59    71  60    69  63    74  65
# NH       40  32    42  34    41  36    42  36    43  37    45  36    46  41
# NJ       78  41    84  43    83  45    88  48    92  50    98  54   101  59
# NM       80  55    78  55    86  57    87  59    93  59    92  59    94  61
# NV       79  55    84  57    86  58    86  60    95  62   100  66   102  68
# NY      110  56   116  58   116  59   119  61   124  64   129  68   137  72
# OH       77  49    78  50    83  53    86  56    93  58    97  61   101  64
# OK       81  58    87  61    92  65    95  69    99  72   101  74   109  80
# OR       84  59    86  61    90  64    92  69    96  69    94  71   105  75
# PA       78  46    79  48    81  50    86  52    92  55    96  58    99  61
# RI       42  30    43  33    44  33    44  35    45  35    44  37    46  39
# SC       69  48    69  50    74  53    84  55    88  59    90  62   102  66
# SD       42  42    49  45    48  48    51  49    50  52    56  53    52  52
# TN       72  48    75  50    80  52    84  56    89  59    96  64   103  66
# TX      135  76   142  78   146  79   151  82   157  84   162  87   165  88
# UT       84  63    88  66    89  67    93  70   100  72   100  74   105  78
# VA       78  48    84  50    88  51    94  54   101  57   107  61   114  65
# VT       32  30    33  32    29  32    32  32    32  36    32  37    30  37
# WA       95  62    96  65   101  66   102  70   108  73   115  77   116  79
# WI       71  49    71  52    74  54    76  56    81  60    87  62    93  64
# WV       47  36    45  37    48  38    49  42    53  45    56  48    59  47
# WY       32  35    30  37    40  39    31  44    33  44    37  45    37  47
#
# year   2007      2008      2009
# sex       F   M     F   M     F   M
# state
# AK       51  50    57  52    52  53 ...
# AL      103  67   105  70   107  72 ...
# AR       92  74   100  72    99  76 ...
# AZ      142  77   142  82   141  84 ...
# CA      164  80   173  83   175  85 ...
# CO      124  79   125  83   127  85 ...
# CT       73  49    77  52    76  54 ...
# DC       67  54    72  52    70  54 ...
# DE       53  43    49  44    52  43 ...
# FL      140  80   145  82   148  85 ...
# GA      148  84   150  89   156  90 ...
# HI       71  63    75  63    70  60 ...
# IA       83  66    86  72    93  74 ...
# ID       80  72    83  75    83  77 ...
# IL      136  83   143  84   142  86 ...
# IN      110  73   113  75   119  81 ...
# KS       96  74   102  76   105  79 ...
# KY       82  58    86  60    88  64 ...
# LA      110  83   110  85   122  90 ...
# MA       85  50    91  54    93  56 ...
# MD      111  65   117  67   114  69 ...
# ME       50  44    52  44    50  47 ...
# MI      109  71   115  74   119  77 ...
# MN       95  65   100  68   102  71 ...
# MO      101  70   105  73   105  76 ...
# MS      100  68   102  72   102  72 ...
# MT       55  59    59  61    58  61 ...
# NC      133  75   138  77   136  81 ...
# ND       45  50    50  49    48  52 ...
# NE       78  68    89  69    90  73 ...
# NH       48  40    49  41    45  42 ...
# NJ      110  61   112  63   114  66 ...
# NM      103  62    98  65   102  67 ...
# NV      108  69   105  72   104  73 ...
# NY      143  74   155  78   155  81 ...
# OH      109  66   111  71   119  74 ...
# OK      113  82   118  86   122  90 ...
# OR      106  77   112  81   110  84 ...
# PA      108  63   112  66   115  67 ...
# RI       44  39    46  42    47  41 ...
# SC      108  69   109  70   109  71 ...
# SD       59  55    60  56    60  59 ...
# TN      107  68   116  73   117  76 ...
# TX      175  91   183  95   188  97 ...
# UT      110  83   112  87   115  91 ...
# VA      120  66   125  70   125  71 ...
# VT       30  38    29  37    32  37 ...
# WA      126  82   129  86   133  90 ...
# WI       97  68   104  71   108  72 ...
# WV       61  49    65  52    64  54 ...
# WY       43  46    43  48    36  50 ...
#
# [51 rows x 26 columns]
